# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
import numpy as np
import seaborn as sns
rcParams["figure.figsize"] = 18, 8
sns.set(rcParams)
sns.set(palette="Set2")
sns.set_context("poster")
np.set_printoptions(precision=4)

# %%
# rename columns
columns = [u'essay_title', u'_projectid', u'date_completed', u'date_expired', u'funding_status', 
           u'grade_level', u'num_donors', u'date_posted', u'poverty_level', u'students_reached', 
           u'project_subject', u'subject_category', u'total_donations', u'tot_price_without_support', 
           u'total_price_with_support', u'_schoolid', u'city', u'state', u'district', u'latitude', 
           u'longitude', u'teach_for_america', u'_teacherid', u'zip', u'_NCESid', u'resource_type', u'county']

df = pd.read_csv("../data/looker_completed_projects_7_14_14.csv", skiprows=1, names=columns,
                 parse_dates = ["date_posted", "date_completed", "date_expired"],
                 true_values="Yes", false_values="No")


year_posted = df.date_posted.apply(lambda date: date.year)
df["year_posted"] = year_posted

df2011 = df[df.year_posted == 2011].copy()
del df

# %%
schools = df2011.groupby("_NCESid").agg({'_projectid': pd.Series.nunique,
                                         'total_donations': np.sum,
                                         'students_reached': np.sum,
                                         'funding_status': lambda S: np.sum(S != 'expired')/np.float(len(S)),
                                         'poverty_level': lambda S: S.iloc[0], # only take one
                                         })

# %%
schools.columns = ['students_reached', 'projects', 'percent_funded', 'total_donations', 'poverty_level']

binary_poverty = pd.get_dummies(schools.poverty_level)

del schools['poverty_level']

schools = pd.concat([schools, binary_poverty], axis=1)

# %%
# user defined module
import sys
sys.path.append('/Users/shinn/zipf/donorschoose/code')
import merge

# %%
import imp
imp.reload(merge)
# Out:
# <module 'merge' from '/Users/shinn/zipf/donorschoose/code/merge.py'>

# %%
NCES_schools = merge.get_NCES_schools(schools.index, columns=["SURVYEAR", "LEAID",
                                                              "FRELCH", "REDLCH", "TOTFRL", 
                                                              "FTE", "ULOCAL", 
                                                              "STATUS", "TYPE",
                                                              "RECONSTY", "RECONSTF", 
                                                              "CHARTR", "MAGNET",
                                                              "TITLEI", "STITLI", 
                                                              "MEMBER", "UG", "TOTETH", 
                                                              "WHITE", "BLACK",
                                                               ])

# %%
# note: there will be multiple entries for districts
NCES_districts = merge.get_NCES_districts(NCES_schools.LEAID, columns=["TOTALREV", "TFEDREV", 
                                                                       "TSTREV", "TLOCREV", 
                                                                       "TOTALEXP", "TCURSSVC",
                                                                       "TCAPOUT",
                                                                       "HR1", "HE1", "HE2",
                                                                       ])

# clean some columns not needed for classification
del NCES_schools["LEAID"]
del NCES_schools["SURVYEAR"]

# %%
df = pd.concat([schools, NCES_schools, NCES_districts], axis=1)

# %%
df.percent_funded.mean()
# Out:
# 0.58351930694039289

# %%
df.iloc[:,-20:]
# Out:
#             CHARTR MAGNET TITLEI STITLI  MEMBER  UG  TOTETH  WHITE  BLACK  \
# _NCESid
# 10000500870    NaN  False   True   True     608 NaN     608    409     15
# 10000500879    NaN  False   True   True     601 NaN     601    363      9
# 10000500889    NaN  False   True   True     639 NaN     639    363      7
# 10000501616    NaN  False   True   True     428 NaN     428    189      3
# 10000600877    NaN  False   True   True     473 NaN     473    323      4
# 10000601413    NaN  False   True   True     527 NaN     527    358      6
# 10000701738    NaN  False  False    NaN     657 NaN     657    490    103
# 10000701742    NaN  False   True  False     586 NaN     586    289    209
# 10000801423    NaN  False   True  False     690 NaN     690    438    170
# 10001102094    NaN  False   True   True     776 NaN     776    500    167
# 10001200123    NaN  False   True   True     489 NaN     489    409      8
# 10001200884    NaN  False   True   True     352 NaN     352    243      9
# 10001201630    NaN  False   True   True     302 NaN     302    238      3
# 10003000003    NaN  False  False    NaN    1008 NaN    1008    588    395
# 10003000004    NaN  False   True   True     698 NaN     698    362    282
# 10006001467    NaN  False   True   True     828 NaN     828    555    242
# 10009000015    NaN  False   True   True     166 NaN     166     13    153
# 10009000020    NaN  False   True   True     233 NaN     233      6    224
# 10024000050    NaN  False   True  False     588 NaN     588    429    139
# 10024000546    NaN  False  False    NaN    1295 NaN    1295    902    279
# 10027000012    NaN  False   True   True     373 NaN     373    224    140
# 10027000024    NaN  False  False    NaN    1282 NaN    1282   1084    125
# 10027000057    NaN  False   True   True     534 NaN     534    484     11
# 10027000058    NaN  False   True   True     309 NaN     309    285      6
# 10027000066    NaN  False   True   True     432 NaN     432    368     32
# 10027000166    NaN  False    NaN    NaN       0 NaN       0      0      0
# 10027000625    NaN  False   True   True     438 NaN     438    406      5
# 10027000648    NaN  False   True   True     683 NaN     683    494    100
# 10027000660    NaN  False  False    NaN     582 NaN     582    501     39
# 10027000665    NaN  False    NaN    NaN       0 NaN       0      0      0
# 10027001477    NaN  False   True   True     912 NaN     912    803     21
# 10027001709    NaN  False  False    NaN     615 NaN     615    434    120
# 10027001710    NaN  False  False    NaN     738 NaN     738    623     76
# 10027001711    NaN  False  False    NaN    1001 NaN    1001    808    126
# 10027001712    NaN  False   True   True    1202 NaN    1202    671    257
# 10027001714    NaN  False   True   True     412 NaN     412    285     91
# 10027001716    NaN  False   True   True    1011 NaN    1011    777     94
# 10027001783    NaN  False   True   True     264 NaN     264    212     36
# 10027001784    NaN  False  False    NaN    1616 NaN    1616   1217    248
# 10027001810    NaN  False  False    NaN    1144 NaN    1144    765    341
# 10027001859    NaN  False  False    NaN     555 NaN     555    340    197
# 10033000087    NaN  False   True  False    1166 NaN    1166     17   1102
# 10033000088    NaN  False   True   True     977 NaN     977     20    922
# 10036000092    NaN  False   True   True     558 NaN     558    336    211
# 10036001480    NaN  False   True   True     329 NaN     329    307      9
# 10039000108    NaN   True   True   True     290 NaN     290      0    290
# 10039000113    NaN  False  False    NaN     606 NaN     606     13    584
# 10039000119    NaN  False  False    NaN     425 NaN     425      6    389
# 10039000128    NaN  False   True   True     252 NaN     252      6    156
# 10039000165    NaN  False   True   True     857 NaN     857      3    849
# 10039001468    NaN  False   True   True     930 NaN     930      8    872
# 10039001484    NaN  False   True   True     817 NaN     817      7    610
# 10039001762    NaN  False   True   True     562 NaN     562      9    548
# 10042000203    NaN  False   True   True     613 NaN     613    501      1
# 10042000205    NaN  False   True   True     688 NaN     688    564      7
# 10054000242    NaN  False   True   True     497 NaN     497    276    159
# 10054001429    NaN  False   True   True     619 NaN     619    600      9
# 10054001488    NaN  False  False    NaN     483 NaN     483    479      2
# 10054001489    NaN  False  False    NaN     549 NaN     549    451     90
# 10054001884    NaN  False  False    NaN     460 NaN     460    408     30
#                ...    ...    ...    ...     ... ...     ...    ...    ...
#
# 10054001429   28924000    521000   571000   3672000       0
# 10054001488   28924000    521000   571000   3672000       0
# 10054001489   28924000    521000   571000   3672000       0
# 10054001884   28924000    521000   571000   3672000       0
#                    ...       ...      ...       ...     ...
#
# [22252 rows x 20 columns]

# %% [markdown]
# ## NCES School Data Notes:
# - UG: Ungraded Students column is mostly null values

# %%
# pd.scatter_matrix(df, figsize=(30,30));
np.corrcoef([1, 2, 3, 4],[1, 2, 3, 4])
# Out:
# array([[ 1.,  1.],
#        [ 1.,  1.]])

# %% [markdown]
# ## Correlation with Number of Projects

# %%
columns = ["TOTFRL", "FRELCH", "REDLCH", "FTE", "UG", "TOTETH", 
           "WHITE", "BLACK", "TOTALREV", "TSTREV", "TLOCREV", 
           "TCAPOUT", "TOTALEXP"]
temp = df[["projects", "MEMBER"] + columns].dropna()
for column in columns:
    print "[{:>8}] {:5.2f}".format( column, np.corrcoef(temp.projects, temp[column]/temp.MEMBER)[0,1] )
# Out:
# [  TOTFRL]  0.17
# [  FRELCH]  0.18
# [  REDLCH] -0.02
# [     FTE]  0.02
# [      UG] -0.01
# [  TOTETH]   nan
# [   WHITE] -0.17
# [   BLACK]  0.08
# [TOTALREV]  0.06
# [  TSTREV]  0.06
# [ TLOCREV]  0.04
# [ TCAPOUT]  0.07
# [TOTALEXP]  0.06

# %%
# projects/teachers
temp = df.projects#/(df.FTE + 1)

print temp.describe()
temp.hist(bins=50)#, log=np.log10)
plt.title("all schools: projects / teachers");
# Out:
# count    22252.000000
# mean         4.400818
# std          8.832545
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          4.000000
# max        244.000000
# Name: projects, dtype: float64

# %% [markdown]
# ## Activity Label

# %%
(df.projects <= 1).sum()/np.float(len(df))
# Out:
# 0.43789322308107137

# %%
temp = df.projects#/(df.FTE + 1)

df['active'] = temp > temp.mean()

# %%
df.active.value_counts()
# Out:
# False    17256
# True      4996
# dtype: int64

# %%
# !../code/feature_importance.py
# Out:
# [fetching data...]
# > /Users/shinn/zipf/donorschoose/code/feature_importance.py(96)fetch_data()
# -> data = data.dropna()
# (Pdb)
# Traceback (most recent call last):
#   File "../code/feature_importance.py", line 135, in <module>
#     project_activity.fetch_data()
#   File "../code/feature_importance.py", line 96, in fetch_data
#     data = data.dropna()
#   File "../code/feature_importance.py", line 96, in fetch_data
#     data = data.dropna()
#   File "/usr/local/Cellar/python/2.7.6_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.py", line 49, in trace_dispatch
#     return self.dispatch_line(frame)
#   File "/usr/local/Cellar/python/2.7.6_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/bdb.py", line 67, in dispatch_line
#     self.user_line(frame)
#   File "/usr/local/Cellar/python/2.7.6_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pdb.py", line 158, in user_line
#     self.interaction(frame, None)
#   File "/usr/local/Cellar/python/2.7.6_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/pdb.py", line 210, in interaction
#     self.cmdloop()
#   File "/usr/local/Cellar/python/2.7.6_1/Frameworks/Python.framework/Versions/2.7/lib/python2.7/cmd.py", line 130, in cmdloop
#     line = raw_input(self.prompt)
# KeyboardInterrupt
